# %% [markdown]
# # 01.3 LTZ - DWD: Clustering

# %% [markdown]
# Notebook to calculate, plot and analyze clusterings of dependance measures.

# %%
from metacatalog import ext, api
from metacatalog_corr import metrics, extension, manage

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# import thesis_functions.py
import sys
sys.path.append('../')

import thesis_functions

# %% [markdown]
# #### seaborn style

# %%
thesis_functions.set_seaborn_style()

# %% [markdown]
# Neues Notebook: Vergleich Correlograms

# %% [markdown]
# #### Create database session:

# %%
UPLOAD = True

CONNECTION = 'mc_corr'

# %%
session = api.connect_database(CONNECTION)
print(session.bind)
# Out:
# Engine(postgresql://postgres:***@localhost:5432/mc_corr)

# %% [markdown]
# ### Load data from metacatalog

# %% [markdown]
# Vorteil DWD: Daten in unterschiedlichen Aufklösungen vorhanden --> spannend für scaling!
# zB precipitation in 1-minütiger Auflösung, aber auch 1-stündlicher Auflösung vorhanden --> Test möglich: wie gut funktioniert scaling

# %% [markdown]
# # EntryGroups

# %%
entry_groups = thesis_functions.load_entrygroups(session)
# Out:
# LTZ Augustenberg
# DWD station Rheinstetten
# Bühlot Dataset
# Sap Flow - Hohes Holz
# LUBW gauge network
# Fendt dataset: Eddy covariance data
# Fendt 1 TERENO preAlpine Observatory / SUSALPS
# Fendt 2 TERENO preAlpine Observatory / SUSALPS
# Fendt 3 TERENO preAlpine Observatory / SUSALPS
# Grasswang TERENO preAlpine Observatory / SUSALPS

# %% [markdown]
# #### Select case01 from correlation_matrix, save to wide df

# %%
df = thesis_functions.get_wide_df(session, filter_identifier='case01')
df.head()
# Out:
#    left_id  right_id                                     identifier   pearson  \
# 0        1         1   [soil_temperature, soil_temperature], case01  1.000000
# 1        1         2   [soil_temperature, global_radiation], case01  0.341284
# 2        1         3  [soil_temperature, relative_humidity], case01 -0.330717
# 3        1         4    [soil_temperature, air_temperature], case01  0.882553
# 4        1         5      [soil_temperature, precipitation], case01  0.016117
#
#    spearman      dcor       mic  kendall_tau  weighted_tau  somers_d  ...  \
# 0  1.000000  1.000000  1.000000     1.000000      1.000000  1.000000  ...
# 1  0.279135  0.329002  0.120572     0.200866      0.507665  0.178536  ...
# 2 -0.295941  0.297018  0.088276    -0.201360     -0.178536 -0.200818  ...
# 3  0.894650  0.872680  0.623052     0.708283      0.877229  0.708532  ...
# 4 -0.039607  0.038660  0.026354    -0.031758     -0.045508 -0.012894  ...
#
# ...

# %%
# all metrics
metrics = ['pearson', 'spearman', 'dcor', 'mic', 'kendall_tau', 'weighted_tau', 'somers_d', 'hoeffdings_d',
           'biweight_mid', 'perc_bend', 'shepherd', 'skipped', 'conditional_entropy', 'mutual_info', 
           'js_divergence', 'js_distance', 'mutual_info_sklearn', 'js_distance_scipy']

# %% [markdown]
# #### Check data with scatterplots to estimate expected correlation

# %%
dwd_entries = []

group_ltz = entry_groups[0]
group_dwd = entry_groups[1]

for e in group_ltz.entries: 
    print(e.id, e.title)

print('___')

for e in group_dwd.entries: 
    if e.datasource.temporal_scale.resolution not in ('P0DT6H0M0S', 'P1DT0H0M0S'):
        dwd_entries.append(e)
        
for e in dwd_entries:
    print(e.id, e.title)
# Out:
# 1 LTZ Augustenberg: soil temperature
# 2 LTZ Augustenberg: global radiation
# 3 LTZ Augustenberg: relative humidity
# 4 LTZ Augustenberg: air temperature
# 5 LTZ Augustenberg: precipitation
# 6 LTZ Augustenberg: wind speed
# ___
# 7 DWD station Rheinstetten, soil temperature, resolution: hourly
# 10 DWD station Rheinstetten, global radiation, resolution: minute_10
# 11 DWD station Rheinstetten, relative humidity, resolution: minute_10
# 12 DWD station Rheinstetten, relative humidity, resolution: hourly
# 15 DWD station Rheinstetten, air temperature, resolution: minute_10
# 16 DWD station Rheinstetten, air temperature, resolution: hourly
# 19 DWD station Rheinstetten, precipitation, resolution: minute_1
# 20 DWD station Rheinstetten, precipitation, resolution: minute_10
# 21 DWD station Rheinstetten, precipitation, resolution: hourly
# 23 DWD station Rheinstetten, wind speed, resolution: minute_10
# 24 DWD station Rheinstetten, wind speed, resolution: hourly

# %%
dwd_ltz_data = {}

# load data
for entry in dwd_entries:
    dat = entry.get_data()
    dwd_ltz_data[entry.title] = dat

for entry in entry_groups[0].entries:
    dat = entry.get_data()
    dwd_ltz_data[entry.title] = dat

    
# plot data
fig, ax = plt.subplots(11, 6, figsize=[20,40])

for i_dwd, dwd_entry in enumerate(dwd_entries):
    dwd_data = dwd_ltz_data[dwd_entry.title]
    
    for i_ltz, ltz_entry in enumerate(group_ltz.entries):
        ltz_data = dwd_ltz_data[ltz_entry.title]
        
        left, right = harmonize_data(dwd_data, ltz_data)
        
        sns.scatterplot(x=left, y=right, ax=ax[i_dwd, i_ltz])
        ax[i_dwd, i_ltz].set_xlabel(dwd_entry.variable.name, fontsize=14.5)
        ax[i_dwd, i_ltz].set_ylabel(ltz_entry.variable.name, fontsize=14.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Expected Correlation

# %%
import minepy

mine = minepy.MINE(alpha=0.6, c=15)
mine.compute_score(left, right)
corr = mine.mic()

corr
# Out:
# /var/folders/ry/cl2x_xyn50n58c9h451mswbr0000gn/T/ipykernel_5659/719448225.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mine.compute_score(left, right)
# 0.6710733271161585

# %%
minepy.pstats([left,right], alpha=0.6, c=15)
# Out:
# /var/folders/ry/cl2x_xyn50n58c9h451mswbr0000gn/T/ipykernel_5659/2260486948.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   minepy.pstats([left,right], alpha=0.6, c=15)
# (array([0.67107333]), array([0.5439798]))

# %%
[left,right]
# Out:
# [array([4.1, 3.9, 3.6, ..., 4.2, 4.5, 3.9]),
#  array([2.77, 2.58, 2.17, ..., 2.28, 2.35, 2.88])]

# %%
# split up variables in identifier into new columns left_variable, right_variable
for idx, row in df.iterrows():
    df.loc[idx, 'left_variable'] = df.loc[idx, 'identifier'].split('[')[1].split(']')[0].replace(',', '').split()[0]
    df.loc[idx, 'right_variable'] = df.loc[idx, 'identifier'].split('[')[1].split(']')[0].replace(',', '').split()[1]

# create keys column for variable combinations with expected correlation (see below)
for idx, row in df.iterrows():
    # sorted: easily get variable combinations in both directions
    df.loc[idx, 'var_combination_key'] = (str(sorted([row.left_variable, row.right_variable])))
    
# median value for all variable combinations
df[select_metrics].groupby(df.var_combination_key).median()
# Out:
#                                              pearson  spearman      dcor  \
# var_combination_key
# ['air_temperature', 'air_temperature']      0.999135  0.999184  0.998777
# ['air_temperature', 'global_radiation']     0.538741  0.475292  0.518745
# ['air_temperature', 'precipitation']        0.006592 -0.053343  0.065305
# ['air_temperature', 'relative_humidity']   -0.570129 -0.520901  0.525160
# ['air_temperature', 'soil_temperature']     0.921370  0.930964  0.917861
# ['air_temperature', 'wind_speed']           0.016016  0.051898  0.095088
# ['global_radiation', 'global_radiation']    0.944313  0.957324  0.943304
# ['global_radiation', 'precipitation']      -0.058146 -0.080803  0.101068
# ['global_radiation', 'relative_humidity']  -0.660156 -0.583674  0.645149
# ['global_radiation', 'soil_temperature']    0.444209  0.361990  0.418882
# ['global_radiation', 'wind_speed']          0.122944  0.213570  0.176738
# ['precipitation', 'precipitation']          0.438740  0.652763  0.663114
# ...

# %% [markdown]
# #### add column expected correlation

# %% [markdown]
#
# | **Criterion**                                                  | **Points** |
# |:---------------------------------------------------------------|-----------:|
# | left_id = right_id                                             |          5 |
# | left_variable = right_variable                                 |          4 |
# | variable_combinations:<br>air_temperature <-> soil_temperature |          3 |
# | variable_combinations:<br>air_temperature <-> global_radiation |          1 |
# | variable_combinations:<br>relative_humidiy <-> air_temperature |          1 |

# %%
# build column of expected correlation
# dictionary: may give different scores for different variable combinations
variable_combinations_strong = ["['air_temperature', 'soil_temperature']"]
variable_combinations_light = ["['air_temperature', 'global_radiation']",
                                "[relativ_humidity, air_temperature]"]



conditions = [
    df['left_id'].eq(df['right_id']),
    df['left_variable'].eq(df['right_variable']),
    df['var_combination_key'].isin(variable_combinations_strong),
    df['var_combination_key'].isin(variable_combinations_light)
    
    # einzelne Variablen Kriterien einführen: soil temp, air temp -> nur system state, zB Niederschlag-Wasserstand nicht -> zeitlicher Versatz
    
    # penalty: zB -5 Punkte wenn mehr als 10 km auseinander -> nicht in DWD, LTZ
]

choices = [5, 4, 3, 2]

# When multiple conditions are satisfied, the first one encountered in conditions is used.
df['expected_corr'] = np.select(conditions, choices, default=0)

# save dataframe
df.to_csv('df_expected_corr.csv')

df.head()
# Out:
#    left_id  right_id                                     identifier   pearson  \
# 0        1         1   [soil_temperature, soil_temperature], case01  1.000000
# 1        1         2   [soil_temperature, global_radiation], case01  0.341284
# 2        1         3  [soil_temperature, relative_humidity], case01 -0.330717
# 3        1         4    [soil_temperature, air_temperature], case01  0.882553
# 4        1         5      [soil_temperature, precipitation], case01  0.016117
#
#    spearman      dcor       mic  kendall_tau  weighted_tau  somers_d  ...  \
# 0  1.000000  1.000000  1.000000     1.000000      1.000000  1.000000  ...
# 1  0.279135  0.329002  0.120572     0.200866      0.507665  0.178536  ...
# 2 -0.295941  0.297018  0.088276    -0.201360     -0.178536 -0.200818  ...
# 3  0.894650  0.872680  0.623052     0.708283      0.877229  0.708532  ...
# 4 -0.039607  0.038660  0.026354    -0.031758     -0.045508 -0.012894  ...
#
# ...

# %% [markdown]
# #### Idee: pairplot (seaborn) with the data! -> find possible correlations by eye, Bewertungstabelle!
# Idee: Punkte einfärben mit expected_corr

# %%
import seaborn as sns

# select_metrics: only plot for chosen metrics (readability)
select_metrics = ['pearson', 'spearman', 'dcor', 'mic', 'kendall_tau', 'mutual_info', 'js_distance']

df_plot = df.copy()
df_plot[select_metrics] = abs(df_plot[select_metrics])

g = sns.pairplot(df_plot, vars=select_metrics, kind="scatter", hue='expected_corr', palette='deep')

plt.show()

# %% [markdown]
# ## This is the main clustering function
# It computes the hierarchical clustering for 1 metric from the wide dataframe created aboce and also plots the corresponding dendrogram.
# The mean value of the previously defined expected correlation is shown on the x-axis.
#
# Another possibility: compare mean value of metric in cluster to mean value of pearson in cluster (**compare_to_pearson=True**)

# %%
# Clustering, comparison to mean(expected_corr)

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

def clustering_and_plot_dendrogram(wide_df, metric, compare_to_pearson=False, **kwargs):
    # wide_df: wide dataframe with metrics as columns
    # metric: metric for clustering computation and plotting, must be a column in wide_df, eg 'pearson'
    # compare_to_pearson: if True, the mean value of pearson is shown for each column, instead of the mean value
    # of expected_correlation
    
    # calculate clustering
    # absolute values of metric column
    X = np.asarray(abs(wide_df[metric]))
    # remove NaN
    X = X[~np.isnan(X)]
    # data has a single feature: reshape
    X = X.reshape(-1, 1)
    # linkage = 'ward': Ward minimizes the sum of squared differences within all clusters. It is a variance-minimizing approach and in this sense is similar to the k-means objective function but tackled with an agglomerative hierarchical approach. 
    # (https://scikit-learn.org/stable/modules/clustering.html#:~:text=the%20merge%20strategy%3A-,Ward,-minimizes%20the%20sum)
    clustering = AgglomerativeClustering(n_clusters=4, linkage='ward', compute_distances=True).fit(X)
    
    def plot_dendrogram(model, **kwargs):
        # Create linkage matrix and then plot the dendrogram if no_plot==False
    
        # create the counts of samples under each node
        counts = np.zeros(model.children_.shape[0])
        n_samples = len(model.labels_)
        for i, merge in enumerate(model.children_):
            current_count = 0
            for child_idx in merge:
                if child_idx < n_samples:
                    current_count += 1  # leaf node
                else:
                    current_count += counts[child_idx - n_samples]
            counts[i] = current_count
    
        linkage_matrix = np.column_stack(
            [model.children_, model.distances_, counts]
        ).astype(float)
    
        # Plot the corresponding dendrogram
        if kwargs.get('no_plot', True):
            return dendrogram(linkage_matrix, **kwargs)
        else:
            dendrogram(linkage_matrix, **kwargs)


    plt.title(f"Hierarchical Clustering Dendrogram for {metric.capitalize()}")
    
    # no_plot: get clustering dict
    dendrogram_dict = plot_dendrogram(clustering, truncate_mode='lastp', p=4, no_plot=True)

    # create labels for each leaf
    label_list = []
    for ivl in dendrogram_dict['ivl']:
        # convert ivl to int
        ivl = int(ivl.split('(')[1].split(')')[0])
        # label_list: (number of points in cluster, mean value of cluster, expected correlation in cluster)
        for i in range(len(dendrogram_dict['ivl'])):
            if len(df[metric][clustering.labels_ == i]) == ivl:
                cluster_points = ivl
                cluster_mean = round(abs(df[metric])[clustering.labels_ == i].mean(), 3)
                if compare_to_pearson:
                    cluster_pearson_mean = round(abs(df.pearson)[clustering.labels_ == i].mean(), 2)  
                    label_list.append(f"{cluster_points, cluster_mean, cluster_pearson_mean}")
                else:
                    cluster_exp_corr_mean = round(abs(df.expected_corr)[clustering.labels_ == i].mean(), 1) 
                    label_list.append(f"{cluster_points, cluster_mean, cluster_exp_corr_mean}")
    
    # create label dictionary with leaves as keys          
    label_dict = {dendrogram_dict["leaves"][ii]: label_list[ii] for ii in range(len(dendrogram_dict["leaves"]))}
    
    # create leaf label function, returing label for each leaf
    def llf(leaf):
        return label_dict[leaf]
    
    # plot the dendrogram
    plot_dendrogram(clustering, truncate_mode='lastp', p=4, no_plot=False, leaf_label_func=llf)
    
    # xlabel
    if compare_to_pearson:
        plt.xlabel(f"(Number of points in node, Mean value of {metric.capitalize()}, Mean value of Pearson")
    else:
        plt.xlabel(f"(Number of points in node, Mean value of {metric.capitalize()}, Mean value of expected correlation")    
    
    plt.tight_layout()
    
    return clustering

# %% [markdown]
# #### In the next cell, clusterings are computed for each metric
# plots are saved

# %%
metrics
# Out:
# <module 'metacatalog_corr.metrics' from '/Users/alexd/GitHub/metacatalog_corr/metacatalog_corr/metrics.py'>

# %%
#metrics = select_metrics

# compare to expected_corr
for metric in metrics:
    try:
        # define figsize
        fig, ax = plt.subplots(figsize=[10,5])

        # compute clustering and dendrogram plot
        clustering_and_plot_dendrogram(df, metric, compare_to_pearson=False)
        
        # save plot
        plt.savefig(f"1D_clustering_plots/{metric}.png")
        plt.close()
        
    except:
        plt.close()
        print('Error:', metric)
    
# compare to pearson
for metric in metrics:
    try:
        # define figsize
        fig, ax = plt.subplots(figsize=[10,5])

        # compute clustering and dendrogram plot
        clustering_and_plot_dendrogram_compare_pearson(df, metric)
        
        # save plot
        plt.savefig(f"1D_clustering_plots_compare_pearson/{metric}.png")
        plt.close()
        
    except:
        plt.close()
        print('Error:', metric)
# Out:
# Error: somers_d
# Error: biweight_mid
# Error: skipped
# Error: somers_d
# Error: biweight_mid
# Error: skipped

# %%
fig, ax = plt.subplots(figsize=[10,5])

clustering_and_plot_dendrogram(df, 'mutual_info', compare_to_pearson=True);

# %% [markdown]
# # Abbildung Metric/Clustering performance

# %%
metrics = select_metrics

df_cluster = pd.DataFrame(columns =['metric', 'cluster', 'metric_mean', 'exp_corr_mean', 'n'])

for metric in metrics:
    try:
        clustering = clustering_and_plot_dendrogram(df, metric)
    
        for i in np.unique(clustering.labels_):
            df_cluster = df_cluster.append({'metric': metric,
                                            'cluster': i,
                                            'metric_mean': abs(df[metric][clustering.labels_ == i]).mean(),
                                            'exp_corr_mean': df.expected_corr[clustering.labels_ == i].mean(),
                                            'n': len(df[metric][clustering.labels_ == i])
                                           }, ignore_index=True)
    except Exception as e:
        print(f"Error {metric}: {e}")
            
        
    
    
df_cluster.index = df_cluster.metric
df_cluster.head()
# Out:
#             metric cluster  metric_mean  exp_corr_mean    n
# metric
# pearson    pearson       0     0.061652       0.106667  150
# pearson    pearson       1     0.571718       0.827586   58
# pearson    pearson       2     0.960863       4.098039   51
# pearson    pearson       3     0.291105       0.266667   30
# spearman  spearman       0     0.485590       0.878049   82

# %%
fig, ax = plt.subplots(1, figsize=[10,8])

sns.scatterplot(x=df_cluster.index, y=df_cluster.metric_mean, 
                hue=df_cluster.exp_corr_mean, size=df_cluster.n, sizes=(10,1000),
                ax=ax)

for i in range(df_cluster.shape[0]):
    plt.text(x=df_cluster.index[i],y=df_cluster.metric_mean[i]+0.03,s=str(round(df_cluster.exp_corr_mean[i], 2)))

ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=6)


    
plt.tight_layout()

# %%
# ----------------------------------------------------------------------------
# Title:   Scientific Visualisation - Python & Matplotlib
# Author:  Nicolas P. Rougier
# License: BSD
# ----------------------------------------------------------------------------
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Some nice but random curves
def curve():
    n = np.random.randint(1, 5)
    centers = np.random.normal(0.0, 1.0, n)
    widths = np.random.uniform(5.0, 50.0, n)
    widths = 10 * widths / widths.sum()
    scales = np.random.uniform(0.1, 1.0, n)
    scales /= scales.sum()
    X = np.zeros(500)
    x = np.linspace(-3, 3, len(X))
    for center, width, scale in zip(centers, widths, scales):
        X = X + scale * np.exp(-(x - center) * (x - center) * width)
    return X


np.random.seed(123)
cmap = mpl.cm.get_cmap("Spectral")
fig = plt.figure(figsize=(8, 8))


ax = None
for n in range(3):
    ax = plt.subplot(1, 3, n + 1, frameon=False, sharex=ax)
    for i in range(50):
        Y = curve()
        X = np.linspace(-3, 3, len(Y))
        ax.plot(X, 3 * Y + i, color="k", linewidth=0.75, zorder=100 - i)
        color = cmap(i / 50)
        ax.fill_between(X, 3 * Y + i, i, color=color, zorder=100 - i)

        # Some random text on the right of the curve
        v = np.random.uniform(0, 1)
        if v < 0.4:
            text = "*"
            if v < 0.05:
                text = "***"
            elif v < 0.2:
                text = "**"
            ax.text(
                3.0,
                i,
                text,
                ha="right",
                va="baseline",
                size=8,
                transform=ax.transData,
                zorder=300,
            )

    ax.yaxis.set_tick_params(tick1On=False)
    ax.set_xlim(-3, 3)
    ax.set_ylim(-1, 53)
    ax.axvline(0.0, ls="--", lw=0.75, color="black", zorder=250)
    ax.text(
        0.0,
        1.0,
        "Value %d" % (n + 1),
        ha="left",
        va="top",
        weight="bold",
        transform=ax.transAxes,
    )

    if n == 0:
        ax.yaxis.set_tick_params(labelleft=True)
        ax.set_yticks(np.arange(50))
        ax.set_yticklabels(["Serie %d" % i for i in range(1, 51)])
        for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(6)
            tick.label.set_verticalalignment("bottom")
    else:
        ax.yaxis.set_tick_params(labelleft=False)


plt.tight_layout()
plt.show()
