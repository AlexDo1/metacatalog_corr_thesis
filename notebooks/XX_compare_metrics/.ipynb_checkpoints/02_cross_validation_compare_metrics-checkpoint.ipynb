# %%
from metacatalog import ext, api

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Local
CONNECTION = 'mc_corr'

session = api.connect_database(CONNECTION)
print(session.bind)
# Out:
# Engine(postgresql://postgres:***@localhost:5432/mc_corr)

# %%
# load table correlation_matrix
sql = 'select * from correlation_matrix'
df = pd.read_sql(sql, session.bind)

# table long to wide format: metrics as columns
df = pd.pivot_table(df, values = ['value'], index=['left_id', 'right_id','identifier'], columns='metric_id').reset_index()

# get metrics for output column names
sql = 'SELECT id, symbol FROM correlation_metrics'
df_metrics = pd.read_sql(sql, session.bind)
dict_metrics = dict(zip(df_metrics.id, df_metrics.symbol))

# rename metric_id to metric_name
df.rename(columns=dict_metrics, inplace=True)

# Multiindex column names from pivot_table() -> flatten to one level
col_names = []
for col in df.columns:
    if col[0] == 'value':
        col_names.append(col[1])
    else:
        col_names.append(col[0])
df.columns = col_names

# drop column 'skipped' -> just calculated for a few entries
df.drop('skipped', axis=1, inplace=True)

df
# Out:
#        left_id  right_id                                         identifier  \
# 0            1         1  [soil_temperature, soil_temperature], all left...
# 1            1         2  [soil_temperature, global_radiation], all left...
# 2            1         3  [soil_temperature, relative_humidity], all lef...
# 3            1         4  [soil_temperature, air_temperature], all left+...
# 4            1         5  [soil_temperature, precipitation], all left+ri...
# ...        ...       ...                                                ...
# 37661     1081        21  [sap_flow, precipitation], all left+right, har...
# 37662     1081        22  [sap_flow, precipitation], all left+right, har...
# 37663     1081        23  [sap_flow, wind_speed], all left+right, harmon...
# 37664     1081        24  [sap_flow, wind_speed], all left+right, harmon...
# 37665     1081        25  [sap_flow, wind_speed], all left+right, harmon...
#
#         pearson  spearman      dcor       mic  kendall_tau  weighted_tau  \
# 0      1.000000  1.000000  1.000000  1.000000     1.000000      1.000000
# 1      0.341284  0.279135  0.329002  0.120572     0.200866      0.507665
# 2     -0.330717 -0.295941  0.297018  0.088276    -0.201360     -0.178536
# 3      0.882553  0.894650  0.872680  0.623052     0.708283      0.877229
# 4      0.016117 -0.039607  0.038660  0.026354    -0.031758     -0.045508
# ...         ...       ...       ...       ...          ...           ...
# 37661 -0.010088 -0.051906  0.015669  0.076785    -0.041778     -0.078958
# 37662 -0.032242 -0.119919  0.038850  0.210635    -0.086722     -0.128537
# 37663 -0.075874  0.266861  0.089013  0.110464     0.179835      0.098534
# 37664 -0.078587  0.299287  0.093700  0.154543     0.201919      0.117670
# 37665 -0.129074 -0.186952  0.142303  0.224126    -0.126579     -0.200117
#
#        hoeffdings_d  biweight_mid  perc_bend  shepherd  conditional_entropy  \
# 0          0.950426           NaN   1.000000  1.000000         1.000000e+00
# 1          0.022349      0.069272   0.315965  0.216286         3.457918e-02
# 2          0.025450     -0.314347  -0.288765 -0.273817         3.406081e-02
# 3          0.410091      0.890731   0.892858  0.900451         2.303798e-01
# 4          0.000094           NaN  -0.024210 -0.057759        -4.440892e-16
# ...             ...           ...        ...       ...                  ...
# 37661     -0.000087           NaN  -0.031017 -0.050721         1.699085e-12
# 37662      0.000806           NaN  -0.066477 -0.152865         1.948299e-01
# 37663      0.023658      0.230599   0.283028  0.273522         6.259236e-02
# 37664      0.030063      0.265650   0.311814  0.306493         9.829399e-02
# 37665      0.009520     -0.073536  -0.237342 -0.168787         1.840338e-01
#
#        mutual_info  js_divergence  js_distance
# 0         1.000000       1.000000     1.000000
# 1         0.045767       0.360186     0.200116
# 2         0.034061       0.027532     0.013862
# 3         0.230380       0.938748     0.752508
# 4         1.109035       0.185853     0.097699
# ...            ...            ...          ...
# 37661 -4375.699521       0.368002     0.205017
# 37662     0.233087       0.594001     0.362819
# 37663     0.062592       0.188007     0.098894
# 37664     0.098294       0.139306     0.072264
# 37665     0.184034       0.013767     0.006907
#
# [37666 rows x 17 columns]

# %%
fig, axs = plt.subplots(5,4)

j = 0

for idx, col in enumerate(df.columns):
    #axs[idx] = df[col].hist()
    axs[idx, j].hist(df[col])
    plt.title(col)
    if j <= 2:
        j += 1
    else:
        j = 0
        
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-4520fa5cba88> in <module>
#       5 for idx, col in enumerate(df.columns):
#       6     #axs[idx] = df[col].hist()
# ----> 7     axs[idx, j].hist(df[col])
#       8     plt.title(col)
#       9     if j <= 2:
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
abs(df.iloc[:,3:]).plot.density(subplots=True, layout=(3,6), xlim=(-2,2))
plt.show()

# %%
plt.hist(df.conditional_entropy, range=(0,1))
plt.show()

# %%
min(df.mutual_info)
# Out:
# -10148.892794375384

# %% [markdown]
# ### 1D clustering pearson

# %%
from sklearn.cluster import AgglomerativeClustering

X = np.asarray(df.pearson)
# remove NaN
X = X[~np.isnan(X)]
# data has a single feature: reshape
X = X.reshape(-1, 1)

# linkage = 'ward': Ward minimizes the sum of squared differences within all clusters. It is a variance-minimizing approach and in this sense is similar to the k-means objective function but tackled with an agglomerative hierarchical approach. 
# (https://scikit-learn.org/stable/modules/clustering.html#:~:text=the%20merge%20strategy%3A-,Ward,-minimizes%20the%20sum)
clustering = AgglomerativeClustering(n_clusters=3, linkage='ward', compute_distances=True).fit(X)

# %% [markdown]
# ### 2D clustering: pearson & spearman

# %%
X_2D = [[row[1].pearson, row[1].spearman] for row in df.iloc[:,3:5].iterrows()]
# remove NaN
X_2D = np.asarray(X_2D)
X_2D = X_2D[~np.isnan(X_2D).any(axis=1)]

clustering = AgglomerativeClustering(n_clusters=3, linkage='ward', compute_distances=True).fit(X_2D)

# %% [markdown]
# ### Dendrogram Plot

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)


plt.title("Hierarchical Clustering Dendrogram")
# plot the top three levels of the dendrogram
plot_dendrogram(clustering, truncate_mode='level', p=1)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.tight_layout()
plt.show()
